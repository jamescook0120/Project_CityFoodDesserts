# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

Consumer1_path = pd.read_csv("Consumption1.csv")
Consumer1_path.columns= ['State', 
                         'Total Personal Consumption Expenditures 2019', 
                         'Housing/Util.', 
                         'Healthcare', 
                         'Off-premises Food/Bev', 
                         'Gasoline/Energy', 
                         'All other Personal Consumptions'] 
Consumer1_path= Consumer1_path.drop(labels=[0,1,2,3,10,17,23,29,31,44,49,55], axis=0)
Consumer1_path= Consumer1_path.reset_index(drop=True)
Consumer1_path.head()
# Out:
#            State Total Personal Consumption Expenditures 2019 Housing/Util.  \
# 0    Connecticut                                        54786         11140
# 1          Maine                                        47351          7444
# 2  Massachusetts                                        56231         10710
# 3  New Hampshire                                        54585         10180
# 4   Rhode Island                                        47045          9248
#
#   Healthcare Off-premises Food/Bev Gasoline/Energy  \
# 0       8218                  3399            1062
# 1       8216                  4299            1889
# 2       9324                  3761             885
# 3       9380                  4091            1531
# 4       7889                  3393            1043
#
#   All other Personal Consumptions
# 0                           30967
# 1                           25503
# 2                           31551
# 3                           29403
# 4                           25472

# %%
Consumer2_path = pd.read_csv("Consumption2.csv")
Consumer2_path.columns= ['State', 
                         '$ by Millions 2017',
                         '$ by Millions 2018', 
                         'Total State Expenditure by Millions 2019', 
                         'Percent Change 2017-18', 
                         'Percent Change 2018-19']
Consumer2_path= Consumer2_path.drop(labels=[0,1,2,3,10,17,23,29,31,44,49,55], axis=0)
Consumer2_path= Consumer2_path.reset_index(drop=True)
Consumer2_path.head()
# Out:
#            State $ by Millions 2017  $ by Millions 2018  \
# 0    Connecticut             182612            189857.0
# 1          Maine              58853             61593.0
# 2  Massachusetts             359649            374378.0
# 3  New Hampshire              68532             71592.0
# 4   Rhode Island              46363             48316.0
#
#    Total State Expenditure by Millions 2019 Percent Change 2017-18  \
# 0                                  195327.0                      4
# 1                                   63650.0                    4.7
# 2                                  387570.0                    4.1
# 3                                   74220.0                    4.5
# 4                                   49838.0                    4.2
#
#    Percent Change 2018-19
# 0                     2.9
# 1                     3.3
# 2                     3.5
# 3                     3.7
# 4                     3.2

# %%
Total_consumption = pd.merge(Consumer1_path, Consumer2_path, left_index=True, on='State')
Total_consumption.head()
# Out:
#            State Total Personal Consumption Expenditures 2019 Housing/Util.  \
# 0    Connecticut                                        54786         11140
# 1          Maine                                        47351          7444
# 2  Massachusetts                                        56231         10710
# 3  New Hampshire                                        54585         10180
# 4   Rhode Island                                        47045          9248
#
#   Healthcare Off-premises Food/Bev Gasoline/Energy  \
# 0       8218                  3399            1062
# 1       8216                  4299            1889
# 2       9324                  3761             885
# 3       9380                  4091            1531
# 4       7889                  3393            1043
#
#   All other Personal Consumptions $ by Millions 2017  $ by Millions 2018  \
# 0                           30967             182612            189857.0
# 1                           25503              58853             61593.0
# 2                           31551             359649            374378.0
# 3                           29403              68532             71592.0
# 4                           25472              46363             48316.0
#
#    Total State Expenditure by Millions 2019 Percent Change 2017-18  \
# 0                                  195327.0                      4
# 1                                   63650.0                    4.7
# 2                                  387570.0                    4.1
# 3                                   74220.0                    4.5
# 4                                   49838.0                    4.2
#
#    Percent Change 2018-19
# 0                     2.9
# 1                     3.3
# 2                     3.5
# 3                     3.7
# 4                     3.2

# %%
Total_consumption= Total_consumption.drop(['$ by Millions 2017', '$ by Millions 2018', "Percent Change 2017-18"],axis=1)
Total_consumption
# Out:
#                    State Total Personal Consumption Expenditures 2019  \
# 0            Connecticut                                        54786
# 1                  Maine                                        47351
# 2          Massachusetts                                        56231
# 3          New Hampshire                                        54585
# 14                           23266                                  417615.0
# 15                           23800                                  499203.0
# 16                           23441                                  251341.0
# 17                           21761                                  124070.0
# 18                           20853                                  113323.0
# 19                           25981                                  265958.0
# 20                           22783                                  253348.0
# 21                           23157                                   80838.0
# 22                           25092                                   40798.0
# 23                           19496                                  174016.0
# 24                           19112                                  105702.0
# 25                           23687                                  923931.0
# 26                           20852                                  404264.0
# 27                           19048                                  162390.0
# 28                           19870                                  173167.0
# 29                           16452                                   96217.0
# 30                           19802                                  389095.0
# 31                           19695                                  185731.0
# 32                           20499                                  256657.0
# 33                           25815                                  397231.0
# 34                           18609                                   66803.0
# 35                           20705                                  276910.0
# 36                           19549                                   77913.0
# 37                           19518                                  140938.0
# 38                           23373                                 1175841.0
# 39                           25493                                  266988.0
# 40                           19676                                   66448.0
# 41                           22719                                   45316.0
# 42                           23446                                  126681.0
# 43                           22791                                   25305.0
# 44                           25560                                   37090.0
# 45                           26539                                 1947590.0
# 46                           26546                                   69993.0
# 47                           25397                                  132958.0
# 48                           22901                                  184344.0
# 49                           26328                                  367599.0
#
#     Percent Change 2018-19
# 0                      2.9
# 1                      3.3
# 2                      3.5
# 3                      3.7
# 4                      3.2
# 5                      1.8
# 6                      3.3
# 7                      3.2
# 8                      2.9
# 9                      3.8
# 10                     4.2
# 11                     3.7
# 12                     2.8
# 13                     3.3
# 14                     3.0
# 15                     2.8
# 16                     2.7
# 17                     2.1
# 18                     2.7
# 19                     3.2
# 20                     3.3
# 21                     2.7
# 22                     3.9
# 23                     3.7
# 24                     3.4
# 25                     4.7
# 26                     3.7
# 27                     3.0
# 28                     3.0
# 29                     2.2
# 30                     4.7
# 31                     4.0
# 32                     3.9
# 33                     3.3
# 34                     2.7
# 35                     4.7
# 36                     2.3
# 37                     3.0
# 38                     4.4
# 39                     5.2
# 40                     4.5
# 41                     4.1
# 42                     5.7
# 43                     2.7
# 44                     3.0
# 45                     5.1
# 46                     3.9
# 47                     3.7
# 48                     4.5
# 49                     5.3

# %%
convert_dict = {'Total Personal Consumption Expenditures 2019': float,
                'Off-premises Food/Bev': float}

Total_consumption= Total_consumption.astype(convert_dict)
print(Total_consumption.dtypes)
# Out:
# State                                            object
# Total Personal Consumption Expenditures 2019    float64
# Housing/Util.                                    object
# Healthcare                                       object
# Off-premises Food/Bev                           float64
# Gasoline/Energy                                  object
# All other Personal Consumptions                  object
# Total State Expenditure by Millions 2019        float64
# Percent Change 2018-19                          float64
# dtype: object

# %%
Total_consumption.plot(x='State', y='Total Personal Consumption Expenditures 2019' , kind='bar', figsize=(7,5)) 
plt.title("Personal Expenditures")
plt.xlabel("")
plt.ylabel("Yearly Expenditures ")
plt.tight_layout()
plt.show
plt.savefig("../../Graphs/US BEA Consumer/Personal Expenditures.png")
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
Total_consumption.plot(x='State', y='Total State Expenditure by Millions 2019', kind='bar', figsize=(7,5)) 
plt.title("State Expenditures")
plt.xlabel("State Name")
plt.ylabel("Yearly Expenditures ")
plt.tight_layout()
plt.show
plt.savefig("../../Graphs/US BEA Consumer/State_exependitures.png")
# Out:
# <img src="data:," width="0">

# %%
Total_consumption.plot(x='State', y=['Total State Expenditure by Millions 2019','Total Personal Consumption Expenditures 2019'] , kind='bar', figsize=(7,5)) 
plt.title("Personal vs State Expenditures")
plt.xlabel("State Name")
plt.ylabel("Yearly Expenditures ")
plt.tight_layout()
plt.savefig("../../Graphs/US BEA Consumer/PersonalvState.png")
plt.show
# Out:
# <img src="data:," width="0">
# <function matplotlib.pyplot.show(block=None)>
