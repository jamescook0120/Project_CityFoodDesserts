# %%
import pandas as pd

# %%
file = "PCE_all.csv"

data = pd.read_csv(file)
data
# Out:
#                                                 GeoFIPS  \
# 0                                                 00000
# 1                                                 00000
# 2                                                 00000
# 3                                                 00000
# 4                                                 00000
# ...                                                 ...
# 1438                                              98000
# 1439                                              98000
# 1440              Note: See the included footnote file.
# 1441  All personal consumption expenditures (PCE) es...
# 1442  Source: U.S. Department of Commerce / Bureau o...
#
#                                                 GeoName  Region  ComponentId  \
# 0                                         United States     NaN          1.0
# 1                                         United States     NaN          1.0
# ...
